# %% [markdown]
# <a href="https://colab.research.google.com/github/PaulGeorge124/CSST101-3B/blob/main/3B_PONCE_EXCER3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Part 1: Defining the Problem and System Design**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# %%
disease = "Diabetes Mellitus"
contributing_factors = [
    "Genetic Predisposition",
    "Obesity",
    "Sedentary Lifestyle",
    "Diet",
    "Age",
    "Ethnicity"
]

print("Disease Selected:", disease)
print("Contributing Factors:")
for factor in contributing_factors:
    print("-", factor)
# Out:
# Disease Selected: Diabetes Mellitus
# Contributing Factors:
# - Genetic Predisposition
# - Obesity
# - Sedentary Lifestyle
# - Diet
# - Age
# - Ethnicity

# %% [markdown]
# # **Part 2: Basic Probability Computation**

# %%
prior_prob = 0.02
test_sens = 0.95
fpr = 0.05
positive_result = 0.06

bayes = test_sens * prior_prob / ((test_sens * prior_prob) + (fpr * (1 - prior_prob)))
print("{:.2f}".format(bayes))
# Out:
# 0.28

# %% [markdown]
# # **Part 3: Decision-Making Simulation**

# %%
treatment = 0.7
benefit = 100
fail = 0.3
loss = 50

expected_health_improvement = treatment * benefit - fail * loss
print("{:.2f}".format(expected_health_improvement))
# Out:
# 55.00

# %% [markdown]
# # **Part 4: Visualize a probability distribution**

# %%
n = 5
p = 0.5

probabilities = [binom.pmf(k, n, p) for k in range(n + 1)]

fig, ax = plt.subplots()
bars = ax.bar(range(n + 1), probabilities, color='skyblue', edgecolor='black')

for bar in bars:
  yval = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom')

ax.set_xlabel('Number of Heads')
ax.set_ylabel('Probability')
ax.set_title('Probability Distribution of Coin Flips')
ax.set_xticks(range(n + 1))
ax.set_xticklabels([str(i) for i in range(n + 1)])
plt.show()

# %% [markdown]
# # **Refelction**

# %%
reflection = """
Probability theory is essential in medical decision-making, particularly for diagnosing diabetes.
 By utilizing Bayesian inference, healthcare professionals can adjust their assessments of a patient's disease likelihood based on new symptoms.
  This method improves diagnostic accuracy and aids in effective resource allocation and patient management strategies.

"""
print(reflection)
# Out:
# Probability theory is essential in medical decision-making, particularly for diagnosing diabetes.
#  By utilizing Bayesian inference, healthcare professionals can adjust their assessments of a patient's disease likelihood based on new symptoms.
#   This method improves diagnostic accuracy and aids in effective resource allocation and patient management strategies.
